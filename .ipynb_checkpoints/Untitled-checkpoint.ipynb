# %%
from src.train.video_dataset import UniDataset

dataset = UniDataset(
    anno_path="/data/maryam.sana/Uni-ControlNet/data/captions.txt",
    root_dir="/data2/local_datasets/vimeo_all/images",
    local_type_list=["r1", "r2", "flow", "depth"],
    global_type_list=[],
    resolution=512,
    drop_txt_prob=0.5,
    keep_all_cond_prob=0.1,
    drop_all_cond_prob=0.1,
    drop_each_cond_prob=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
)
